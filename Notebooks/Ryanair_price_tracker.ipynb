# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time

# %%
url = 'https://www.glassdoor.de/Job/data-analyst-jobs-SRCH_KO0,12.htm'

# %%
driver = webdriver.Chrome('/Users/anton/Ironhack/chromedriver')

# %%
driver.get(url)
time.sleep(2) #experiment with timer to fetch all the data

# %%
page = driver.page_source

# %%
driver.quit()

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)
# Out:
# <html data-triggered="true" lang="de" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head>
# <title>Jobs für Data analyst | Glassdoor.de</title>
# ...

# %%
price = soup.find("div", class_="price-wrapper").find('span').text

# %%
print(price)
# Out:
#  Value Flugpreis
